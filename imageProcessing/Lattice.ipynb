# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, axis = plt.subplots(figsize = (5, 5))
for i in range(-3, 4):
    for j in range(-3, 4):
        axis.plot(i * 1/2, j * 1, '.', color = 'black')
        axis.plot(i, j, '.', color = 'red')
# axis.axis('off')
