# %%
from utility import *

# %%
photo = rgb2gray(imread('/Users/hunfen/OneDrive/General Files/ゼミー/20201210/CIMG0019.JPG'))
fig, axis = plt.subplots()
axis.imshow(photo, cmap = 'gray')
axis.axis('off')
fig.tight_layout();

# fig.savefig('/Users/hunfen/OneDrive/General Files/ゼミー/20201210/FeSe2.5hrsAnnealing.jpg', dpi = 600)
